# %%
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager 
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import numpy as np
import pandas as pd

# %%
#driver configuration
opciones=Options()

opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)
opciones.headless=False    # si True, no aperece la ventana (headless=no visible)
opciones.add_argument('--start-maximized')         # comienza maximizado
#opciones.add_argument('user-data-dir=selenium')    # mantiene las cookies
#opciones.add_extension('driver_folder/adblock.crx')       # adblocker
opciones.add_argument('--incognito')

# %%
url1_10='https://www.linkedin.com/search/results/companies/?companyHqGeo=%5B%22100994331%22%5D&companySize=%5B%22B%22%5D&hasJobs=%5B%221%22%5D&origin=FACETED_SEARCH&sid=CmD'
url11_50='https://www.linkedin.com/search/results/companies/?companyHqGeo=%5B%22100994331%22%5D&companySize=%5B%22C%22%5D&hasJobs=%5B%221%22%5D&origin=FACETED_SEARCH&sid=f9%40'
url51_200='https://www.linkedin.com/search/results/companies/?companyHqGeo=%5B%22100994331%22%5D&companySize=%5B%22D%22%5D&hasJobs=%5B%221%22%5D&origin=FACETED_SEARCH&sid=cN2'
url201_500='https://www.linkedin.com/search/results/companies/?companyHqGeo=%5B%22100994331%22%5D&companySize=%5B%22E%22%5D&hasJobs=%5B%221%22%5D&origin=FACETED_SEARCH&sid=)(T'
url501_1000='https://www.linkedin.com/search/results/companies/?companyHqGeo=%5B%22100994331%22%5D&companySize=%5B%22F%22%5D&hasJobs=%5B%221%22%5D&origin=FACETED_SEARCH&sid=9P3'
url1001_5000='https://www.linkedin.com/search/results/companies/?companyHqGeo=%5B%22100994331%22%5D&companySize=%5B%22G%22%5D&hasJobs=%5B%221%22%5D&origin=FACETED_SEARCH&sid=%3AMO'
url5001_10000='https://www.linkedin.com/search/results/companies/?companyHqGeo=%5B%22100994331%22%5D&companySize=%5B%22H%22%5D&hasJobs=%5B%221%22%5D&origin=FACETED_SEARCH&sid=%2Ctk'
url_mas_10000='https://www.linkedin.com/search/results/companies/?companyHqGeo=%5B%22100994331%22%5D&companySize=%5B%22I%22%5D&hasJobs=%5B%221%22%5D&origin=FACETED_SEARCH&sid=FMF'

urls=[url1_10,url11_50,url51_200,url201_500,url501_1000,url1001_5000,url5001_10000,url_mas_10000]

# %%
''''def extraerlinks (driver):
    tabla1=driver.find_element(By.XPATH,'//*[@id="main"]/div/div/div[1]')
    a=tabla1.find_elements(By.TAG_NAME,'a')
    classname=tabla1.find_elements(By.CLASS_NAME,'app-aware-link')#[1].get_attribute('href')
    links_to_sql=[]

    for i in range(len(classname)):
        if 'company' in classname[i].get_attribute('href'):
            links_to_sql.append(classname[i].get_attribute('href'))
        else: pass
    links_unique=list(dict.fromkeys(links_to_sql))'''

# %%
''''PATH=ChromeDriverManager().install()      
driver = webdriver.Chrome(PATH, options=opciones)
driver.get(url1_10)
time.sleep(2)
driver.find_element(By.XPATH,'/html/body/div[2]/main/p[1]/a').click() #ya tienes cuenta, inicia sesion
time.sleep(2)
driver.find_element(By.ID,'username').send_keys('proyectfinale@gmail.com')
time.sleep(2)
driver.find_element(By.ID,'password').send_keys('IronhackPF1')
time.sleep(2)
driver.find_element(By.XPATH,'//*[@id="organic-div"]/form/div[3]/button').click()'''''
#tabla1=driver.find_element(By.XPATH,'//*[@id="main"]/div/div/div[1]')
#a=tabla1.find_elements(By.TAG_NAME,'a')
#classname=tabla1.find_elements(By.CLASS_NAME,'app-aware-link')#[1].get_attribute('href')


#extraerlinks(driver)

# %%
''''links_to_sql=[]
for i in range(len(classname)):
    if 'company' in classname[i].get_attribute('href'):
        links_to_sql.append(classname[i].get_attribute('href'))
    else: pass
links_unique=list(dict.fromkeys(links_to_sql))
links_unique''''''

# %%
''''driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(2)
driver.find_element(By.XPATH,'//button[@type="button" and @aria-label="Siguiente"]').click()'''
# Out:
# '\'driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")\ntime.sleep(2)\ndriver.find_element(By.XPATH,\'//button[@type="button" and @aria-label="Siguiente"]\').click()'

# %%
''''tabla1=driver.find_element(By.XPATH,'//*[@id="main"]/div/div/div[1]')
a=tabla1.find_elements(By.TAG_NAME,'a')
classname=tabla1.find_elements(By.CLASS_NAME,'app-aware-link')#[1].get_attribute('href')


for i in range(len(classname)):
    if 'company' in classname[i].get_attribute('href'):
        links_to_sql.append(classname[i].get_attribute('href'))
    else: pass
links_unique=list(dict.fromkeys(links_to_sql))
links_unique'''
# Out:
# '\'tabla1=driver.find_element(By.XPATH,\'//*[@id="main"]/div/div/div[1]\')\na=tabla1.find_elements(By.TAG_NAME,\'a\')\nclassname=tabla1.find_elements(By.CLASS_NAME,\'app-aware-link\')#[1].get_attribute(\'href\')\n\n\nfor i in range(len(classname)):\n    if \'company\' in classname[i].get_attribute(\'href\'):\n        links_to_sql.append(classname[i].get_attribute(\'href\'))\n    else: pass\nlinks_unique=list(dict.fromkeys(links_to_sql))\nlinks_unique'

# %%
#FINAL

# %%
PATH=ChromeDriverManager().install()      
driver = webdriver.Chrome(PATH, options=opciones)
driver.get(url1_10)
time.sleep(2)
driver.find_element(By.XPATH,'/html/body/div[2]/main/p[1]/a').click() #ya tienes cuenta, inicia sesion
time.sleep(2)
driver.find_element(By.ID,'username').send_keys('proyectfinale@gmail.com')
time.sleep(2)
driver.find_element(By.ID,'password').send_keys('IronhackPF1')
time.sleep(2)
driver.find_element(By.XPATH,'//*[@id="organic-div"]/form/div[3]/button').click()
# Out:
# /var/folders/bg/_zqwsn3n223bm28sndqq_c4h0000gn/T/ipykernel_10995/2469508086.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(PATH, options=opciones)

# %%
def extraerlink(url,driver):
    
    driver.get(url)
    tabla1=driver.find_element(By.XPATH,'//*[@id="main"]/div/div/div[1]')
    a=tabla1.find_elements(By.TAG_NAME,'a')
    classname=tabla1.find_elements(By.CLASS_NAME,'app-aware-link')#[1].get_attribute('href')
    links_to_sql=[]

    for i in range(len(classname)):
        if 'company' in classname[i].get_attribute('href'):
            links_to_sql.append(classname[i].get_attribute('href'))
        else: pass
    links_unique=list(dict.fromkeys(links_to_sql))
    return links_unique

# %%
from tqdm import tqdm_notebook as tqdm

# %%
''''#hacerlo todo de una a ver.....
PATH=ChromeDriverManager().install()      
driver = webdriver.Chrome(PATH, options=opciones)
driver.get(url1_10)
time.sleep(2)
driver.find_element(By.XPATH,'/html/body/div[2]/main/p[1]/a').click() #ya tienes cuenta, inicia sesion
time.sleep(2)
driver.find_element(By.ID,'username').send_keys('proyectfinale@gmail.com')
time.sleep(2)
driver.find_element(By.ID,'password').send_keys('IronhackPF1')
time.sleep(2)
driver.find_element(By.XPATH,'//*[@id="organic-div"]/form/div[3]/button').click()
tabla1=driver.find_element(By.XPATH,'//*[@id="main"]/div/div/div[1]')
a=tabla1.find_elements(By.TAG_NAME,'a')
classname=tabla1.find_elements(By.CLASS_NAME,'app-aware-link')#[1].get_attribute('href')'''
# Out:
# /var/folders/bg/_zqwsn3n223bm28sndqq_c4h0000gn/T/ipykernel_9642/2454135220.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(PATH, options=opciones)

# %%
#EL BUENO, no

links_final=[]


for url in tqdm(urls):
    for i in tqdm(range(0,100)):
        try:
            url=driver.current_url
            links_final.append(extraerlink(url,driver)) #función definida
            time.sleep(3)
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(2)
            driver.find_element(By.XPATH,'//button[@type="button" and @aria-label="Siguiente"]').click()
            time.sleep(3)
            url=driver.current_url
        except: pass



print('ha parado el bucle')
#el resultado es links_final
# Out:
# /var/folders/bg/_zqwsn3n223bm28sndqq_c4h0000gn/T/ipykernel_10995/1338830002.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for url in tqdm(urls):
#   0%|          | 0/8 [00:00<?, ?it/s]
# /var/folders/bg/_zqwsn3n223bm28sndqq_c4h0000gn/T/ipykernel_10995/1338830002.py:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm(range(0,100)):
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# ha parado el bucle

# %%
data_links=pd.DataFrame(links_final)

# %%
data_links.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 data_links.tail()
#
# NameError: name 'data_links' is not defined

# %%
data_links.shape
# Out:
# (800, 10)

# %%
data_links.to_csv('links_PF.csv')  #por convenio sep=','

# %%
prueba = []

for link in links_final:
    for l in link:
        prueba.append(l)

# %%
len(np.unique(prueba))
# Out:
# 508

# %%
prueba
# Out:
# ['https://www.linkedin.com/company/trabajosremotos/',
#  'https://www.linkedin.com/company/fororecursoshumanos/',
#  'https://www.linkedin.com/company/finnovista/',
#  'https://www.linkedin.com/company/profesional-independiente_6/',
#  'https://www.linkedin.com/company/campusfinanciero/',
#  'https://www.linkedin.com/company/grupo-moveo/',
#  'https://www.linkedin.com/company/gemstones-arch/',
#  'https://www.linkedin.com/company/institutoiecah/',
#  'https://www.linkedin.com/company/selint-international/',
#  'https://www.linkedin.com/company/villarroel-&-hunter/',
#  'https://www.linkedin.com/company/contigo-energ%C3%ADa/',
#  'https://www.linkedin.com/company/grupo-xito-rrhh-sl/',
#  'https://www.linkedin.com/company/victoria-selection-&-search/',
#  'https://www.linkedin.com/company/magallanes-consultores/',
#  'https://www.linkedin.com/company/headway-executive-search---iesf/',
#  'https://www.linkedin.com/company/acertto-headhunting/',
#  'https://www.linkedin.com/company/hubtalent/',
#  'https://www.linkedin.com/company/selectube/',
#  'https://www.linkedin.com/company/montanes-i-sole/',
#  'https://www.linkedin.com/company/clinica-medico-dental-alcobendas-sl/',
#  'https://www.linkedin.com/company/decorando-tu-espacio-studio-sl/',
#  'https://www.linkedin.com/company/amazonas-peluqueros/',
#  'https://www.linkedin.com/company/global-psicoavanza-slp/',
#  'https://www.linkedin.com/company/line-legends-group-sl/',
#  'https://www.linkedin.com/company/agy-events-sl/',
#  'https://www.linkedin.com/company/mi-guarida-pulida-sl/',
#  'https://www.linkedin.com/company/casas-prefabricadas-steel-home-espa%C3%B1a-sl/',
#  'https://www.linkedin.com/company/clinica-medico-dental-alcobendas-sl/',
#  'https://www.linkedin.com/company/decorando-tu-espacio-studio-sl/',
#  'https://www.linkedin.com/company/amazonas-peluqueros/',
#  'https://www.linkedin.com/company/global-psicoavanza-slp/',
#  'https://www.linkedin.com/company/line-legends-group-sl/',
#  'https://www.linkedin.com/company/agy-events-sl/',
#  ...]

# %%
#Este sí funciona. Hacer en casa porque se va el wifi


links_final2=[]
posible = True
for url in tqdm(urls):
    while(posible):
        try:    
            links_final2.append(extraerlink2(url)) #función definida
            time.sleep(3)
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(2)
            url1=driver.current_url
            driver.find_element(By.XPATH,'//button[@type="button" and @aria-label="Siguiente"]').click()
            time.sleep(3)
            url=driver.current_url
            
            if url==url1:
                break
        except: posible=False



print('ha parado el bucle')
#el resultado es links_final
# Out:
# /var/folders/bg/_zqwsn3n223bm28sndqq_c4h0000gn/T/ipykernel_15579/3213974708.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for url in tqdm(urls):
#   0%|          | 0/8 [00:00<?, ?it/s]
# ha parado el bucle

# %%
len(links_final3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 len(links_final3)
#
# NameError: name 'links_final3' is not defined

# %%
data_links_1=pd.DataFrame(links_final2)
data_links_1.to_csv('links_PF_1.csv')

# %%
def extraerlink2(url):
    
    driver.get(url)
    tabla1=driver.find_element(By.XPATH,'//*[@id="main"]/div/div/div[1]')
    a=tabla1.find_elements(By.TAG_NAME,'a')
    classname=tabla1.find_elements(By.CLASS_NAME,'app-aware-link')#[1].get_attribute('href')
    links_to_sql=[]

    for i in range(len(classname)):
        if 'company' in classname[i].get_attribute('href'):
            links_to_sql.append(classname[i].get_attribute('href'))
        else: pass
    links_unique=list(dict.fromkeys(links_to_sql))
    return links_unique

# %%
PATH=ChromeDriverManager().install()      
driver = webdriver.Chrome(PATH, options=opciones)
driver.get(url1_10)
time.sleep(2)
driver.find_element(By.XPATH,'/html/body/div[2]/main/p[1]/a').click() #ya tienes cuenta, inicia sesion
time.sleep(2)
driver.find_element(By.ID,'username').send_keys('proyectfinale@gmail.com')
time.sleep(2)
driver.find_element(By.ID,'password').send_keys('IronhackPF1')
time.sleep(2)
driver.find_element(By.XPATH,'//*[@id="organic-div"]/form/div[3]/button').click()
# Out:
# /var/folders/bg/_zqwsn3n223bm28sndqq_c4h0000gn/T/ipykernel_15579/2469508086.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(PATH, options=opciones)

# %% [markdown]
# # quiero hacer lo mismo pero con empresas que ofrezcan trabajo data analysis en españa o en el mundo o a saber

# %%
url_data= 'https://www.linkedin.com/search/results/companies/?companyHqGeo=%5B%22100994331%22%5D&hasJobs=%5B%221%22%5D&keywords=data%20&origin=FACETED_SEARCH&sid=sSu'

# %%
PATH=ChromeDriverManager().install()      
driver = webdriver.Chrome(PATH, options=opciones)
driver.get(url_data)
time.sleep(2)
driver.find_element(By.XPATH,'/html/body/div[2]/main/p[1]/a').click() #ya tienes cuenta, inicia sesion
time.sleep(2)
driver.find_element(By.ID,'username').send_keys('proyectfinale@gmail.com')
time.sleep(2)
driver.find_element(By.ID,'password').send_keys('IronhackPF1')
time.sleep(2)
driver.find_element(By.XPATH,'//*[@id="organic-div"]/form/div[3]/button').click()
# Out:
# /var/folders/bg/_zqwsn3n223bm28sndqq_c4h0000gn/T/ipykernel_15579/2345709443.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(PATH, options=opciones)

# %%
driver.get(url_data)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:398, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     397     else:
# --> 398         conn.request(method, url, **httplib_request_kw)
#     400 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     401 # legitimately able to close the connection after sending a valid response.
#     402 # With this behaviour, the received response is still readable.
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connection.py:239, in HTTPConnection.request(self, method, url, body, headers)
#     238     headers["User-Agent"] = _get_default_user_agent()
# --> 239 super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#
# File ~/opt/anaconda3/lib/python3.9/http/client.py:1285, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1284 """Send a complete request to the server."""
# -> 1285 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~/opt/anaconda3/lib/python3.9/http/client.py:1331, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1330     body = _encode(body, 'body')
# -> 1331 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~/opt/anaconda3/lib/python3.9/http/client.py:1280, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1279     raise CannotSendHeader()
# -> 1280 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~/opt/anaconda3/lib/python3.9/http/client.py:1040, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1039 del self._buffer[:]
# -> 1040 self.send(msg)
#    1042 if message_body is not None:
#    1043
#    1044     # create a consistent interface to message_body
#
# File ~/opt/anaconda3/lib/python3.9/http/client.py:980, in HTTPConnection.send(self, data)
#     979 if self.auto_open:
# --> 980     self.connect()
#     981 else:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connection.py:205, in HTTPConnection.connect(self)
#     204 def connect(self):
# --> 205     conn = self._new_conn()
#     206     self._prepare_conn(conn)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f8e1fef6dc0>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 driver.get(url_data)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:446, in WebDriver.get(self, url)
#     442 def get(self, url: str) -> None:
#     443     """
#     444     Loads a web page in the current browser session.
#     445     """
# --> 446     self.execute(Command.GET, {'url': url})
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:432, in WebDriver.execute(self, driver_command, params)
#     429         params['sessionId'] = self.session_id
#     431 params = self._wrap_value(params)
# --> 432 response = self.command_executor.execute(driver_command, params)
#     433 if response:
#     434     self.error_handler.check_response(response)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/remote_connection.py:344, in RemoteConnection.execute(self, command, params)
#     342 data = utils.dump_json(params)
#     343 url = f"{self._url}{path}"
# --> 344 return self._request(command_info[0], url, body=data)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/remote_connection.py:366, in RemoteConnection._request(self, method, url, body)
#     363     body = None
#     365 if self.keep_alive:
# --> 366     response = self._conn.request(method, url, body=body, headers=headers)
#     367     statuscode = response.status
#     368 else:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/request.py:78, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      74     return self.request_encode_url(
#      75         method, url, fields=fields, headers=headers, **urlopen_kw
#      76     )
#      77 else:
# ---> 78     return self.request_encode_body(
#      79         method, url, fields=fields, headers=headers, **urlopen_kw
#      80     )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/request.py:170, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     167 extra_kw["headers"].update(headers)
#     168 extra_kw.update(urlopen_kw)
# --> 170 return self.urlopen(method, url, **extra_kw)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     374     response = conn.urlopen(method, url, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#     379 if not redirect_location:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:813, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     808 if not conn:
#     809     # Try again
#     810     log.warning(
#     811         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     812     )
# --> 813     return self.urlopen(
#     814         method,
#     815         url,
#     816         body,
#     817         headers,
#     818         retries,
#     819         redirect,
#     820         assert_same_host,
#     821         timeout=timeout,
#     822         pool_timeout=pool_timeout,
#     823         release_conn=release_conn,
#     824         chunked=chunked,
#     825         body_pos=body_pos,
#     826         **response_kw
#     827     )
#     829 # Handle redirect?
#     830 redirect_location = redirect and response.get_redirect_location()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:813, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     808 if not conn:
#     809     # Try again
#     810     log.warning(
#     811         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     812     )
# --> 813     return self.urlopen(
#     814         method,
#     815         url,
#     816         body,
#     817         headers,
#     818         retries,
#     819         redirect,
#     820         assert_same_host,
#     821         timeout=timeout,
#     822         pool_timeout=pool_timeout,
#     823         release_conn=release_conn,
#     824         chunked=chunked,
#     825         body_pos=body_pos,
#     826         **response_kw
#     827     )
#     829 # Handle redirect?
#     830 redirect_location = redirect and response.get_redirect_location()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:813, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     808 if not conn:
#     809     # Try again
#     810     log.warning(
#     811         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     812     )
# --> 813     return self.urlopen(
#     814         method,
#     815         url,
#     816         body,
#     817         headers,
#     818         retries,
#     819         redirect,
#     820         assert_same_host,
#     821         timeout=timeout,
#     822         pool_timeout=pool_timeout,
#     823         release_conn=release_conn,
#     824         chunked=chunked,
#     825         body_pos=body_pos,
#     826         **response_kw
#     827     )
#     829 # Handle redirect?
#     830 redirect_location = redirect and response.get_redirect_location()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:785, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     782 elif isinstance(e, (SocketError, HTTPException)):
#     783     e = ProtocolError("Connection aborted.", e)
# --> 785 retries = retries.increment(
#     786     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     787 )
#     788 retries.sleep()
#     790 # Keep track of the error for the retry warning.
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     581 new_retry = self.new(
#     582     total=total,
#     583     connect=connect,
#    (...)
#     588     history=history,
#     589 )
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#     596 return new_retry
#
# MaxRetryError: HTTPConnectionPool(host='localhost', port=56928): Max retries exceeded with url: /session/81835e397f415b8b95f49132bb5175b3/url (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f8e1fef6dc0>: Failed to establish a new connection: [Errno 61] Connection refused'))

# %%
#Este sí funciona. Hacer en casa porque se va el wifi
url_data=[]
posible = True
for url in url_data:
    while(posible):
        try:    
            url_data.append(extraerlink2(url)) #función definida
            time.sleep(3)
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(2)
            url1=driver.current_url
            driver.find_element(By.XPATH,'//button[@type="button" and @aria-label="Siguiente"]').click()
            time.sleep(3)
            url=driver.current_url
            
            if url==url1:
                break
        except: posible=False



print('ha parado el bucle')
#el resultado es links_final
# Out:
# ha parado el bucle

# %%
links_data_Madrid
# Out:
# [['https://www.linkedin.com/company/data-modul-ag/',
#   'https://www.linkedin.com/company/keepler/',
#   'https://www.linkedin.com/company/artyco-the-data-driven-company/',
#   'https://www.linkedin.com/company/lis-data-solutions-sp/',
#   'https://www.linkedin.com/company/strategy-big-data/',
#   'https://www.linkedin.com/company/garaje-de-ideas/',
#   'https://www.linkedin.com/company/mcreif/',
#   'https://www.linkedin.com/company/researchablenl/',
#   'https://www.linkedin.com/company/bbva/',
#   'https://www.linkedin.com/company/telef%C3%B3nica/'],
#  ['https://www.linkedin.com/company/data-modul-ag/',
#   'https://www.linkedin.com/company/keepler/',
#   'https://www.linkedin.com/company/artyco-the-data-driven-company/',
#   'https://www.linkedin.com/company/lis-data-solutions-sp/',
#   'https://www.linkedin.com/company/strategy-big-data/',
#   'https://www.linkedin.com/company/garaje-de-ideas/',
#   'https://www.linkedin.com/company/mcreif/',
#   'https://www.linkedin.com/company/researchablenl/',
#   'https://www.linkedin.com/company/bbva/',
#   'https://www.linkedin.com/company/telef%C3%B3nica/'],
#  ['https://www.linkedin.com/company/data-modul-ag/',
#   'https://www.linkedin.com/company/keepler/',
#   'https://www.linkedin.com/company/artyco-the-data-driven-company/',
#   'https://www.linkedin.com/company/lis-data-solutions-sp/',
#   'https://www.linkedin.com/company/strategy-big-data/',
#   'https://www.linkedin.com/company/garaje-de-ideas/',
#   'https://www.linkedin.com/company/mcreif/',
#   'https://www.linkedin.com/company/researchablenl/',
#   'https://www.linkedin.com/company/bbva/',
#   'https://www.linkedin.com/company/telef%C3%B3nica/'],
#  ['https://www.linkedin.com/company/data-modul-ag/',
#   'https://www.linkedin.com/company/keepler/',
#   'https://www.linkedin.com/company/artyco-the-data-driven-company/',
#   'https://www.linkedin.com/company/lis-data-solutions-sp/',
#   'https://www.linkedin.com/company/strategy-big-data/',
#   'https://www.linkedin.com/company/garaje-de-ideas/',
#   'https://www.linkedin.com/company/mcreif/',
#   'https://www.linkedin.com/company/researchablenl/',
#   'https://www.linkedin.com/company/bbva/',
#   'https://www.linkedin.com/company/telef%C3%B3nica/']]
