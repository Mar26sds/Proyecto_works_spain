# %%
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager 
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import numpy as np
import pandas as pd
from tqdm import tqdm_notebook as tqdm

# %%
#Cargar los datos y hacer una lista de todas las url

# %%
df_link_ciudades_españa=pd.read_csv('/Users/mar/Proyecto final linkedin selenium/df_link_ciudades_españa/df_link_ciudades_españa.csv')

# %%
df_link_ciudades_españa.Link[0]
# Out:
# 'https://www.linkedin.com/company/garaje-de-ideas/'

# %%
urls=[]

for i in range(len(df_link_ciudades_españa.Link)):
    urls.append(df_link_ciudades_españa.Link[i])
    
len(urls)
# Out:
# 2638

# %%
# Out:
# ['https://www.linkedin.com/company/garaje-de-ideas/',
#  'https://www.linkedin.com/company/gw-consulting/',
#  'https://www.linkedin.com/company/epam-systems/',
#  'https://www.linkedin.com/company/ustglobal/',
#  'https://www.linkedin.com/company/hays/',
#  'https://www.linkedin.com/company/scc/',
#  'https://www.linkedin.com/company/ciklum/',
#  'https://www.linkedin.com/company/first-point-group/',
#  'https://www.linkedin.com/company/atsistemas/',
#  'https://www.linkedin.com/company/idealista-com/',
#  'https://www.linkedin.com/company/plexus-tech/',
#  'https://www.linkedin.com/company/viewnext/',
#  'https://www.linkedin.com/company/izertis/',
#  'https://www.linkedin.com/company/plainconcepts/',
#  'https://www.linkedin.com/company/sngular/',
#  'https://www.linkedin.com/company/between-tech/',
#  'https://www.linkedin.com/company/imf-smart-education/',
#  'https://www.linkedin.com/company/omega-crm-consulting/',
#  'https://www.linkedin.com/company/opinno/',
# ...

# %%
#driver configuration
opciones=Options()

opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)
opciones.headless=False    # si True, no aperece la ventana (headless=no visible)
opciones.add_argument('--start-maximized')         # comienza maximizado
#opciones.add_argument('user-data-dir=selenium')    # mantiene las cookies
#opciones.add_extension('driver_folder/adblock.crx')       # adblocker
opciones.add_argument('--incognito')

# %%
PATH=ChromeDriverManager().install()      
driver = webdriver.Chrome(PATH, options=opciones)
driver.get(url[0])
#log
time.sleep(2)
driver.find_element(By.XPATH,'//*[@id="main-content"]/div/form/p/button').click() #ya tienes cuenta, inicia sesion
time.sleep(2)
driver.find_element(By.XPATH,'//*[@id="session_key"]').send_keys('proyectfinale@gmail.com')
time.sleep(2)
driver.find_element(By.XPATH,'//*[@id="session_password"]').send_keys('IronhackPF1')
time.sleep(2)
driver.find_element(By.XPATH,'//*[@id="main-content"]/div/div/div/form/button').click()
driver.get(url[0])
# Out:
# /var/folders/bg/_zqwsn3n223bm28sndqq_c4h0000gn/T/ipykernel_24888/970816609.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(PATH, options=opciones)
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Input In [84], in <cell line: 6>()
#       4 #log
#       5 time.sleep(2)
# ----> 6 driver.find_element(By.XPATH,'//*[@id="main-content"]/div/form/p/button').click() #ya tienes cuenta, inicia sesion
#       7 time.sleep(2)
#       8 driver.find_element(By.XPATH,'//*[@id="session_key"]').send_keys('proyectfinale@gmail.com')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webelement.py:88, in WebElement.click(self)
#      86 def click(self) -> None:
#      87     """Clicks the element."""
# ---> 88     self._execute(Command.CLICK_ELEMENT)
#
# ...

# %%
nombre=driver.find_elements(By.TAG_NAME,'h1')[0].text
nombre
# Out:
# 'GWC Data Cloud'

# %%
click_detalles=driver.find_elements(By.TAG_NAME,'a')[10].click()
#click_detalles.get_attributes('href')
click_detalles

# %%
resumen=driver.find_elements(By.TAG_NAME,'p')[1].text
resumen
# Out:
# 'Somos una agencia de Diseño UX, Tecnología Data y Growth. En Garaje de ideas diseñamos servicios y productos basados en datos que mejoran la vida de las personas, transforman los negocios y tienen un impacto cultural y económico positivo... pero sin parecernos a otros, siendo nosotros mismos, creando un nuevo modelo de consultoría.'

# %%
sitio_web=driver.find_elements(By.CLASS_NAME,'link-without-visited-state')[2].text
sitio_web
# Out:
# 'https://garajedeideas.com'

# %%
telefono=driver.find_elements(By.CLASS_NAME,'link-without-visited-state')[5].text
telefono
# Out:
# '+34 910 51 94 90'

# %%
sector=driver.find_elements(By.TAG_NAME,'dd')[2].text
sector
# Out:
# 'Servicios de TI y consultoría de TI'

# %%
tamaño_empresa=driver.find_elements(By.TAG_NAME,'dd')[3].text
tamaño_empresa
# Out:
# '51-200 empleados'

# %%
especialidad=driver.find_elements(By.TAG_NAME,'dd')[6].text
especialidad
# Out:
# 'Design-driven Innovation, Strategic Design, Digital Strategy, User Experience Design y Growth'

# %%
fundacion=driver.find_elements(By.TAG_NAME,'dd')[5].text
fundacion
# Out:
# '2015'

# %%
def extraerinfo(url):
    driver.get(url)
    try:
        nombre=driver.find_elements(By.TAG_NAME,'h1')[0].text
    except:
        nombre='Unknown'
    try:
        click_detalles=driver.find_elements(By.TAG_NAME,'a')[10].click()
        time.sleep(2)
    except:
        resumen='Unknown'
        sitio_web='Unknown'
        telefono='Unknown'
        sector='Unknown'
        tamaño_empresa='Unknown'
        especialidad='Unknown'
        fundacion='Unknown'
    try:
        resumen=resumen=driver.find_elements(By.TAG_NAME,'p')[1].text
    except:
        resumem='Unknown'
    try:
        sitio_web=driver.find_elements(By.CLASS_NAME,'link-without-visited-state')[2].text
    except:
        sitio_web='Unknown'
    try:
        telefono=driver.find_elements(By.CLASS_NAME,'link-without-visited-state')[5].text
    except:
        telefono='Unknown'
    try:
        sector=driver.find_elements(By.TAG_NAME,'dd')[2].text
    except:
        sector='Unknown'
    try:
        tamaño_empresa=driver.find_elements(By.TAG_NAME,'dd')[3].text
    except:
        tamaño_empresa='Unknown'
    try:
        especialidad=driver.find_elements(By.TAG_NAME,'dd')[6].text
    except:
        especialidad='Unknown'
    try:
        fundacion=driver.find_elements(By.TAG_NAME,'dd')[5].text  
    except:
        fundacion='Unknown'
    #quiero crear un diccionario vacío e ir añadiendo
    
    dic={'url':url,
        'nombre':nombre,
        'resumen':resumen,
        'especialidad':especialidad,
        'sector':sector,
        'tamaño_empresa':tamaño_empresa,
        'fundacion':fundacion,
        'sitio_web':sitio_web,
        'teléfono':telefono}

    #o también se puede añadir a una lista vacía y luego esa a otra 
    datos_empresa=[url,nombre,resumen,especialidad,sector,tamaño_empresa,fundacion,
                  sitio_web,telefono]

    
    #sería primero hacer la lista datos_empresa y luego append a lista datos todas como lista de listas y eso ya a df
    
    return dic

# %%
PATH=ChromeDriverManager().install()      
driver = webdriver.Chrome(PATH, options=opciones)
driver.get(urls[0])
#log
time.sleep(2)
driver.find_element(By.XPATH,'//*[@id="main-content"]/div/form/p/button').click() #ya tienes cuenta, inicia sesion
time.sleep(2)
driver.find_element(By.XPATH,'//*[@id="session_key"]').send_keys('proyectfinale@gmail.com')
time.sleep(2)
driver.find_element(By.XPATH,'//*[@id="session_password"]').send_keys('IronhackPF1')
time.sleep(2)
driver.find_element(By.XPATH,'//*[@id="main-content"]/div/div/div/form/button').click()
driver.get(url[0])
# Out:
# /var/folders/bg/_zqwsn3n223bm28sndqq_c4h0000gn/T/ipykernel_24888/2696842979.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(PATH, options=opciones)
# ---------------------------------------------------------------------------
# InvalidArgumentException                  Traceback (most recent call last)
# Input In [233], in <cell line: 13>()
#      11 time.sleep(2)
#      12 driver.find_element(By.XPATH,'//*[@id="main-content"]/div/div/div/form/button').click()
# ---> 13 driver.get(url[0])
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:446, in WebDriver.get(self, url)
#     442 def get(self, url: str) -> None:
#     443     """
#     444     Loads a web page in the current browser session.
#     445     """
# --> 446     self.execute(Command.GET, {'url': url})
#
# ...

# %%
extraerinfo('https://www.linkedin.com/company/garaje-de-ideas/')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [202], in <cell line: 1>()
# ----> 1 extraerinfo('https://www.linkedin.com/company/garaje-de-ideas/')
#
# Input In [197], in extraerinfo(url)
#       6 time.sleep(2)
#       7 resumen=resumen=driver.find_elements(By.TAG_NAME,'p')[1].text
# ----> 8 sitio_web=driver.find_elements(By.CLASS_NAME,'link-without-visited-state')[2].text
#       9 telefono=driver.find_elements(By.CLASS_NAME,'link-without-visited-state')[5].text
#      10 sector=driver.find_elements(By.TAG_NAME,'dd')[2].text
#
# IndexError: list index out of range

# %%
lista_datos_todas=[]
lista_dic=[]

for i in tqdm(urls[1925:]):
    lista_datos_todas.append(extraerinfo(i))
# Out:
# /var/folders/bg/_zqwsn3n223bm28sndqq_c4h0000gn/T/ipykernel_24888/1451168029.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm(urls[1925:]):
#   0%|          | 0/713 [00:00<?, ?it/s]

# %%
lista_datos_todas
# Out:
# [['https://www.linkedin.com/company/gw-consulting/',
#   'GWC Data Cloud',
#   'Somos una empresa especialista en servicios Cloud con Data Center Propio. Ofrecemos soluciones de nube privada y pública, así como interconexión de sedes y soluciones de Backup/DR.',
#   '2015',
#   'Telecomunicaciones',
#   '11-50 empleados',
#   'Sevilla, Sevilla',
#   'http://www.gwc.global',
#   '900 730 330'],
#  ['https://www.linkedin.com/company/gw-consulting/',
#   'GWC Data Cloud',
#   'Somos una empresa especialista en servicios Cloud con Data Center Propio. Ofrecemos soluciones de nube privada y pública, así como interconexión de sedes y soluciones de Backup/DR.',
#   '2015',
#   'Telecomunicaciones',
#   '11-50 empleados',
#   'Sevilla, Sevilla',
#   'http://www.gwc.global',
#   '900 730 330'],
#  ['https://www.linkedin.com/company/gw-consulting/',
#   'GWC Data Cloud',
# ...

# %%
len(lista_datos_todas)
# Out:
# 1478

# %%
lista_datos_todas_1=lista_datos_todas

# %%
len(lista_datos_todas)
# Out:
# 1478

# %%
lista_1=pd.DataFrame(lista_datos_todas_1)

# %%
lista_1.to_csv('/Users/mar/Proyecto final linkedin selenium/lista_1.csv')

# %%
len(lista_datos_todas)
lista_datos_todas_2=lista_datos_todas
lista_2=pd.DataFrame(lista_datos_todas_2)

# %%
lista_2.to_csv('/Users/mar/Proyecto final linkedin selenium/lista_2.csv')

# %%
df_datos1=pd.DataFrame()
df_datos1=pd.concat([lista_1,lista_2])

# %%
df_datos1.reset_index(drop=True, inplace=True)
df_datos1.to_csv('/Users/mar/Proyecto final linkedin selenium/da_datos1.csv')

# %%
len(df_datos1)
# Out:
# 1927

# %%
lista_datos_todas_3=lista_datos_todas
lista_3=pd.DataFrame(lista_datos_todas_3)
len(lista_datos_todas_3)
# Out:
# 713

# %%
lista_3=pd.DataFrame(lista_datos_todas_3)

# %%
df_datos_final=pd.DataFrame()
df_datos_final=pd.concat([lista_1,lista_2,lista_3])

# %%
df_datos_final.reset_index(drop=True, inplace=True)
df_datos_final.to_csv('/Users/mar/Proyecto final linkedin selenium/datos_final.csv')

# %%
#ahora tengo que limpiar los datos que desgraciadamente voy a usar spreadsheet
