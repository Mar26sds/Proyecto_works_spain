# %%
# %pip install selenium
# %pip install webdriver-manager
# %pip install ipywidgets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 995.2/995.2 kB 2.3 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.9/384.9 kB 1.1 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 2.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager 
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import numpy as np
import pandas as pd
from tqdm import tqdm_notebook as tqdm
from tqdm import tqdm

# %%
data=pd.read_csv('/Users/mar/Proyecto final linkedin selenium/base_datos_limpia/data_limpia.csv')

# %%
nombres=data['Nombre de la Empresa']

# %%
len(nombres)
# Out:
# 2638

# %%
list(nombres)
# Out:
# ['Garaje de ideas | Diseño, tecnología, data, SEO, SEM',
#  'GWC Data Cloud',
#  'EPAM Systems',
#  'UST',
#  'Hays',
#  'SCC',
#  'Ciklum',
#  'First Point Group',
#  'atSistemas',
#  'idealista',
#  'Plexus Tech',
#  'VIEWNEXT',
#  'IZERTIS',
#  'Plain Concepts',
#  'SNGULAR',
#  'Between Technology',
#  'IMF Smart Education',
#  'Omega CRM',
#  'Opinno',
#  'GRUPO SOLUTIO',
#  'Nfq Advisory, Solutions, Outsourcing',
#  'NWorld Advisory, Tech & Operations',
#  'Savana',
#  'VISEO IBERIA',
#  'Kabel',
#  'atmira',
#  'Zemsania Global Group',
#  'NUNSYS',
#  'RavenPack',
#  'EDICOM',
#  'eºmergya',
#  'OpenSistemas',
#  'Grupo ICA',
#  'ACCOM',
#  'COS Global Services',
#  'Nextail',
#  'Iwantic',
#  'Clikalia',
#  'Sothis',
#  'Grupo Trevenque',
#  'Grupo CMC',
#  'Cívica',
#  'Predictiva.io',
#  'PKF Attest',
#  'Atrys',
#  'EIP - Escuela Internacional de Posgrados',
#  'Bravent',
#  'Skylife Engineering S. L.',
#  'Neteris Consulting',
#  'VISEO',
#  'Wizeline',
#  'Scopely',
# ...

# %%
#driver configuration
opciones=Options()

opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)
opciones.headless=False    # si True, no aperece la ventana (headless=no visible)
opciones.add_argument('--start-maximized')         # comienza maximizado
#opciones.add_argument('user-data-dir=selenium')    # mantiene las cookies
#opciones.add_extension('driver_folder/adblock.crx')       # adblocker
opciones.add_argument('--incognito')

# %%
url='https://www.coordenadas-gps.com'

# %%
PATH=ChromeDriverManager().install()      
driver = webdriver.Chrome(PATH, options=opciones)
driver.get(url)
time.sleep(3)
driver.find_element(By.XPATH,'//*[@id="address"]').clear()
#driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[2]/div/div/div[1]').click()
# Out:
# /var/folders/bg/_zqwsn3n223bm28sndqq_c4h0000gn/T/ipykernel_39697/1743903683.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(PATH, options=opciones)

# %%
coordenada=[]

for i in tqdm(range(len(nombres))):
    try:
        driver.switchTo().alert().accept()
    except:
        continue
    driver.find_element(By.XPATH,'//*[@id="address"]').clear()
    time.sleep(1)
    
    try:
        driver.switchTo().alert().accept()
    except:
        continue
    
    driver.find_element(By.XPATH,'//*[@id="address"]').send_keys(nombres[i])
    time.sleep(1)
    
    try:
        driver.switchTo().alert().accept()
    except:
        continue
    
    driver.find_element(By.XPATH,'//*[@id="wrap"]/div[2]/div[3]/div[1]/form[1]/div[2]/div/button').click()
    time.sleep(1)
    
    try:
        driver.switchTo().alert().accept()
    except:
        continue
    
    lat0=driver.find_element(By.XPATH,'//*[@id="info_window"]').text
    lat1=lat0.split('\n')[1]
    lat2=lat1.split('|')
    lat3=lat2[0].split(': ')
    lat=lat3[1]
    
    long0=driver.find_element(By.XPATH,'//*[@id="info_window"]').text
    long1=long0.split('\n')[1]
    long2=lat1.split('|')
    long3=long2[1].split(': ')
    long=long3[1]
    
    coor=[lat,long]
    coordenada.append(coor)
# Out:
# 100%|███████████████████████████████████| 2638/2638 [00:00<00:00, 781838.18it/s]

# %%
coordenada

# %%
driver.find_element(By.XPATH,'//*[@id="address"]').clear()

# %%
type(nombres)
# Out:
# pandas.core.series.Series

# %%
driver.find_element(By.XPATH,'//*[@id="address"]').send_keys(nombres[2])

# %%
driver.find_element(By.XPATH,'//*[@id="wrap"]/div[2]/div[3]/div[1]/form[1]/div[2]/div/button').click()

# %%
#lat=driver.find_element(By.XPATH,'//*[@id="latitude"]')
#lon=driver.find_element(By.XPATH,'//*[@id="longitude"]')

# %%
lat0=driver.find_element(By.XPATH,'//*[@id="info_window"]').text
lat1=lat0.split('\n')[1]
lat2=lat1.split('|')
lat3=lat2[0].split(': ')
lat=lat3[1]
lat
# Out:
# '55.611735 '

# %%
long0=driver.find_element(By.XPATH,'//*[@id="info_window"]').text
long1=long0.split('\n')[1]
long2=lat1.split('|')
long3=long2[1].split(': ')
long=long3[1]
long
# Out:
# '37.665831'

# %%
coordenada=[]

for i in tqdm(range(len(nombres))):
    try:
        driver.find_element(By.XPATH,'//*[@id="address"]').clear()
        time.sleep(1)

        driver.find_element(By.XPATH,'//*[@id="address"]').send_keys(nombres[i])
        time.sleep(1)

        driver.find_element(By.XPATH,'//*[@id="wrap"]/div[2]/div[3]/div[1]/form[1]/div[2]/div/button').click()
        time.sleep(1)


        lat0=driver.find_element(By.XPATH,'//*[@id="info_window"]').text
        lat1=lat0.split('\n')[1]
        lat2=lat1.split('|')
        lat3=lat2[0].split(': ')
        lat=lat3[1]

        long0=driver.find_element(By.XPATH,'//*[@id="info_window"]').text
        long1=long0.split('\n')[1]
        long2=lat1.split('|')
        long3=long2[1].split(': ')
        long=long3[1]

        coor=[lat,long]
        coordenada.append(coor)
    except:
            try:
                driver.switchTo().alert().accept()
                driver.find_element(By.XPATH,'//*[@id="address"]').clear()
                time.sleep(1)

                driver.find_element(By.XPATH,'//*[@id="address"]').send_keys(nombres[i])
                time.sleep(1)

                driver.find_element(By.XPATH,'//*[@id="wrap"]/div[2]/div[3]/div[1]/form[1]/div[2]/div/button').click()
                time.sleep(1)
                lat0=driver.find_element(By.XPATH,'//*[@id="info_window"]').text
                lat1=lat0.split('\n')[1]
                lat2=lat1.split('|')
                lat3=lat2[0].split(': ')
                lat=lat3[1]

                long0=driver.find_element(By.XPATH,'//*[@id="info_window"]').text
                long1=long0.split('\n')[1]
                long2=lat1.split('|')
                long3=long2[1].split(': ')
                long=long3[1]

                coor=[lat,long]
                coordenada.append(coor)
            except:
                    pass
# Out:
# 100%|███████████████████████████████████████| 2638/2638 [01:18<00:00, 33.67it/s]

# %%
# Out:
# 7

# %%
coordenada=[]

no_pass_nombres=[]

for i in tqdm(range(len(nombres))):
    try:
        driver.find_element(By.XPATH,'//*[@id="address"]').clear()
        time.sleep(1)

        driver.find_element(By.XPATH,'//*[@id="address"]').send_keys(nombres[i])
        time.sleep(1)

        driver.find_element(By.XPATH,'//*[@id="wrap"]/div[2]/div[3]/div[1]/form[1]/div[2]/div/button').click()
        time.sleep(1)


        lat0=driver.find_element(By.XPATH,'//*[@id="info_window"]').text
        lat1=lat0.split('\n')[1]
        lat2=lat1.split('|')
        lat3=lat2[0].split(': ')
        lat=lat3[1]

        long0=driver.find_element(By.XPATH,'//*[@id="info_window"]').text
        long1=long0.split('\n')[1]
        long2=lat1.split('|')
        long3=long2[1].split(': ')
        long=long3[1]

        coor=[lat,long]
        coordenada.append(coor)
        
    except:
        no_pass_nombres.append(nombres[i])
        
        
#alert = world.browser.switch_to.alert
#alert.accept()
# Out:
# 100%|███████████████████████████████████████| 2638/2638 [01:44<00:00, 25.24it/s]

# %%
len(coordenada)
# Out:
# 1609

# %%
len(no_pass_nombres)
# Out:
# 1029

# %%
#este

coordenada=[]

no_pass_nombres=[]

for i in tqdm(range(len(nombres))):
    try:
        driver.find_element(By.XPATH,'//*[@id="address"]').clear()
        time.sleep(1)

        driver.find_element(By.XPATH,'//*[@id="address"]').send_keys(nombres[i])
        time.sleep(1)

        driver.find_element(By.XPATH,'//*[@id="wrap"]/div[2]/div[3]/div[1]/form[1]/div[2]/div/button').click()
        time.sleep(2)
        
        lat0=driver.find_element(By.XPATH,'//*[@id="info_window"]').text
        lat1=lat0.split('\n')[1]
        lat2=lat1.split('|')
        lat3=lat2[0].split(': ')
        lat=lat3[1]

        long0=driver.find_element(By.XPATH,'//*[@id="info_window"]').text
        long1=long0.split('\n')[1]
        long2=lat1.split('|')
        long3=long2[1].split(': ')
        long=long3[1]

        coor=[lat,long]
        coordenada.append(coor)

    except:
        coordenada.append('unknown')
        no_pass_nombres.append(nombres[i])
# Out:
# 100%|█████████████████████████████████████| 2638/2638 [3:09:48<00:00,  4.32s/it]

# %%
coordenada
# Out:
# [['59.2823 ', '10.33004'],
#  ['39.4803 ', '-97.64928'],
#  ['55.611735 ', '37.665831'],
#  ['29.961078 ', '-81.340501'],
#  ['30.04479 ', '-98.039313'],
#  ['27.557585 ', '80.699477'],
#  ['50.422389 ', '30.505906'],
#  'unknown',
#  ['40.393715 ', '-3.676087'],
#  ['40.416024 ', '-3.696213'],
#  'unknown',
#  ['36.718612 ', '-4.496911'],
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  ['12.4989 ', '124.6377'],
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  ['-12.763924 ', '-40.969305'],
#  ['38.09032 ', '-92.29267'],
#  ['14.18455 ', '12.003467'],
#  ['41.311421 ', '19.446037'],
#  'unknown',
#  'unknown',
#  'unknown',
#  ['14.718301 ', '-17.27781'],
#  'unknown',
#  'unknown',
#  ['-13.716985 ', '-76.205805'],
#  ['26.407384 ', '93.25513'],
#  'unknown',
#  'unknown',
#  'unknown',
#  'unknown',
#  ['28.486359 ', '-16.317929'],
#  ['41.648971 ', '-4.713868'],
#  ['40.483359 ', '-3.667923'],
#  ['59.927468 ', '40.396485'],
#  'unknown',
# ...

# %%
PATH=ChromeDriverManager().install()      
driver = webdriver.Chrome(PATH, options=opciones)
driver.get(url)
time.sleep(3)
driver.find_element(By.XPATH,'//*[@id="address"]').clear()
#driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[2]/div/div/div[1]').click()
# Out:
# /var/folders/bg/_zqwsn3n223bm28sndqq_c4h0000gn/T/ipykernel_39697/1743903683.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(PATH, options=opciones)

# %%
coordenadas=pd.read_csv('/Users/mar/Proyecto final linkedin selenium/coor/coord.csv')

# %%
coordenadas=pd.DataFrame(coordenada)

# %%
coordenadas.head()
# Out:
#             0           1     2     3     4     5     6
# 0    59.2823     10.33004  None  None  None  None  None
# 1    39.4803    -97.64928  None  None  None  None  None
# 2  55.611735    37.665831  None  None  None  None  None
# 3  29.961078   -81.340501  None  None  None  None  None
# 4   30.04479   -98.039313  None  None  None  None  None

# %%
colnames='latitude','longitude','1','2','3','4','5'
coordenadas.columns=colnames

# %%
coordenadas.head()
# Out:
#      latitude   longitude     1     2     3     4     5
# 0    59.2823     10.33004  None  None  None  None  None
# 1    39.4803    -97.64928  None  None  None  None  None
# 2  55.611735    37.665831  None  None  None  None  None
# 3  29.961078   -81.340501  None  None  None  None  None
# 4   30.04479   -98.039313  None  None  None  None  None

# %%
coordenadas.to_csv('/Users/mar/Proyecto final linkedin selenium/coor/coord.csv')

# %%
coordenadas.drop(['1','2','3','4','5'], axis=1, inplace=True)

# %%
coordenadas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2638 entries, 0 to 2637
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   latitude   2638 non-null   object
#  1   longitude  2638 non-null   object
# dtypes: object(2)
# memory usage: 41.3+ KB

# %%
coordenadas = coordenadas.astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [171], in <cell line: 1>()
# ----> 1 coordenadas = coordenadas.astype(float)
#
# File ~/opt/anaconda3/envs/Streamlit/lib/python3.9/site-packages/pandas/core/generic.py:6245, in NDFrame.astype(self, dtype, copy, errors)
#    6238     results = [
#    6239         self.iloc[:, i].astype(dtype, copy=copy)
#    6240         for i in range(len(self.columns))
#    6241     ]
#    6243 else:
#    6244     # else, only a single dtype is given
# -> 6245     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6246     return self._constructor(new_data).__finalize__(self, method="astype")
#    6248 # GH 33113: handle empty frame or series
#
# File ~/opt/anaconda3/envs/Streamlit/lib/python3.9/site-packages/pandas/core/internals/managers.py:446, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
coordenadas.head()
# Out:
#      latitude   longitude
# 0    59.2823     10.33004
# 1    39.4803    -97.64928
# 2  55.611735    37.665831
# 3  29.961078   -81.340501
# 4   30.04479   -98.039313

# %%
coordenadas['latitude'][0]
# Out:
# '59.2823 '

# %%
bad_index=[]

for i in range(len(coordenadas)):
    if coordenadas['latitude'][i]=='u':
        bad_index.append(i)

# %%
len(bad_index)
# Out:
# 1433

# %%
coordenadas.drop(bad_index, inplace=True)

# %%
coordenadas
# Out:
#         latitude   longitude
# 0       59.2823     10.33004
# 1       39.4803    -97.64928
# 2     55.611735    37.665831
# 3     29.961078   -81.340501
# 4      30.04479   -98.039313
# ...          ...         ...
# 2622        8.5        -11.5
# 2623         40           -4
# 2626  51.537422    -0.061001
# 2627   -2.91673     104.7458
# 2630  -34.57016   -58.450006
#
# [1205 rows x 2 columns]

# %%
list(coordenadas.itertuples())[0][1]
# Out:
# '59.2823 '

# %%
coordenadas.to_csv('/Users/mar/Proyecto final linkedin selenium/coor/coordenadas.csv')

# %%
#borrar los valores con u y n, guardar y pasarlo al py.
